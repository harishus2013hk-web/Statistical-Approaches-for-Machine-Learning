# %%
import matplotlib.pyplot as plt

#List of Marks for 30 students
scores = [55, 67, 78, 90, 45, 88, 76, 95, 62, 70,
          85, 60, 73, 80, 92, 58, 66, 77, 84, 69,
          74, 81, 59, 68, 72, 87, 91, 63, 75, 79]
plt.hist(scores,5,color="Blue",edgecolor="black")       #Create Histogram
plt.xlabel("Score")
plt.ylabel("Students")
plt.title("Distribution of Exam Scores")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
